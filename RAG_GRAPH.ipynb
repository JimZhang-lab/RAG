# %% [markdown]
# ### GraphRAG Quick-Start

# %%
# !pip install graphrag
# !mkdir -p ./graphrag/input
# !curl https://www.gutenberg.org/cache/epub/24022/pg24022.txt > ./graphrag/input/book.txt
# !python -m graphrag.index --init --root ./graphrag

# %% [markdown]
# ###  Run and initialize the RAG index

# %%
# !python -m graphrag.index --root ./graphrag
# Out:
# 🚀 Reading settings from graphrag/settings.yaml
# ⠹ GraphRAG Indexer
# ⠹ GraphRAG Indexer e.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠴ GraphRAG Indexer
# ...

# %% [markdown]
# ### start query

# %%
# !python -m graphrag.query \
--root ./graphrag \
--method global \
"这个故事中的主要主题是什么？用中文回答"
# Out:
# INFO: Reading settings from graphrag/settings.yaml
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/graphrag/query/__main__.py", line 92, in <module>
#     run_global_search(
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/graphrag/query/cli.py", line 97, in run_global_search
#     final_nodes: pd.DataFrame = pd.read_parquet(
#                                 ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/pandas/io/parquet.py", line 667, in read_parquet
#     return impl.read(
#            ^^^^^^^^^^
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/pandas/io/parquet.py", line 267, in read
#     path_or_handle, handles, filesystem = _get_path_or_handle(
#                                           ^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python -m graphrag.query \
--root ./graphrag \
--method local \
"萧炎会什么招数?用中文回答"
# Out:
# INFO: Reading settings from graphrag/settings.yaml
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/graphrag/query/__main__.py", line 83, in <module>
#     run_local_search(
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/graphrag/query/cli.py", line 138, in run_local_search
#     final_nodes = pd.read_parquet(data_path / "create_final_nodes.parquet")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/pandas/io/parquet.py", line 667, in read_parquet
#     return impl.read(
#            ^^^^^^^^^^
#   File "/opt/anaconda3/envs/graphrag/lib/python3.11/site-packages/pandas/io/parquet.py", line 267, in read
#     path_or_handle, handles, filesystem = _get_path_or_handle(
# ...
